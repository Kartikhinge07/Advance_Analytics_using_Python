# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv(r"E:\Adv Analytics\Datasets\iris.csv")
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['Petal.Width'].kurtosis()
# Out:
# -1.340603996612646

# %%
plt.hist(iris['Petal.Width'])
plt.show()

# %%
diamonds = pd.read_csv(r"E:\Adv Analytics\Datasets\diamonds.csv")
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds['price'].kurtosis()
# Out:
# 2.17769575924869

# %%
plt.hist(diamonds['price'])
plt.show()

# %%
# Covariance

# %%
a=np.array([2,4,5,7,9,13,20])
b=np.array([45,43,36,28,23,19,10])
np.cov(a,b)
# Out:
# array([[ 38.28571429, -76.0952381 ],
#        [-76.0952381 , 166.47619048]])

# %%
np.cov(b,a)
# Out:
# array([[166.47619048, -76.0952381 ],
#        [-76.0952381 ,  38.28571429]])

# %%
np.var(a)
# Out:
# 32.816326530612244

# %%
np.var(b)
# Out:
# 142.69387755102042

# %%
np.mean(a)
# Out:
# 8.571428571428571

# %%
np.median(a)
# Out:
# 7.0

# %%
np.cov(a,b, bias =True) # (divide by n , if bias is true) , (divide by N-1,if bias is false)
# Out:
# array([[ 32.81632653, -65.2244898 ],
#        [-65.2244898 , 142.69387755]])

# %%
np.corrcoef(a,b)
# Out:
# array([[ 1.        , -0.95315392],
#        [-0.95315392,  1.        ]])

# %%
iris.corr()
# Out:
# C:\Users\KARTIK\AppData\Local\Temp\ipykernel_4736\2141086772.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris.corr()
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Sepal.Length      1.000000    -0.117570      0.871754     0.817941
# Sepal.Width      -0.117570     1.000000     -0.428440    -0.366126
# Petal.Length      0.871754    -0.428440      1.000000     0.962865
# Petal.Width       0.817941    -0.366126      0.962865     1.000000

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
cts = diamonds.groupby('cut')['price'].mean()
cts1 =cts.reset_index()
sns.barplot(data =cts1 , x='cut',y='price')
plt.ylabel('mean price')
plt.show()

# %%
plt.boxplot(diamonds['price'])
plt.show()

# %%
q1=diamonds['price'].quantile(q=0.25)
q3=diamonds['price'].quantile(q=0.75)
iqr= q3-q1
print("Inter Quartile range" , iqr)
lim_iqr=1.5*iqr
print(lim_iqr)
# Out:
# Inter Quartile range 4374.25
# 6561.375

# %%
upper_iqr = q3+lim_iqr
upper_iqr
# Out:
# 11885.625

# %%
lower_iqr = q1-lim_iqr # lower_iqr = q1 -(1.5*iqr)
lower_iqr
# Out:
# -5611.375

# %%
diamonds[diamonds['price']>upper_iqr]
# Out:
#        carat        cut color clarity  depth  table  price      x      y     z
# 23820   1.17      Ideal     F    VVS1   62.1   57.0  11886   6.82   6.73  4.21
# 23821   2.08      Ideal     I     SI2   62.0   56.0  11886   8.21   8.10  5.06
# 23822   1.70    Premium     I     VS2   62.2   58.0  11888   7.65   7.60  4.74
# 23823   1.09      Ideal     F      IF   61.6   55.0  11888   6.59   6.65  4.08
# 23824   1.68      Ideal     E     SI2   60.4   55.0  11888   7.79   7.70  4.68
# 23825   1.54    Premium     F     SI1   60.9   59.0  11897   7.56   7.46  4.57
# 23826   2.00    Premium     J     SI2   61.9   55.0  11899   8.09   8.06  5.00
# 23827   2.00    Premium     J     SI2   59.8   60.0  11899   8.13   8.09  4.85
# 23828   1.56    Premium     F     SI1   60.7   59.0  11901   7.55   7.45  4.55
# 23829   2.01    Premium     F     SI2   62.0   60.0  11903   7.88   7.82  4.87
# 23830   1.52  Very Good     H    VVS2   63.0   60.0  11904   7.25   7.30  4.58
# ...

# %%
diamonds[diamonds['price']<lower_iqr]
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %%
outliers_df =diamonds[(diamonds['price']>upper_iqr) |(diamonds['price']<lower_iqr)]
outliers_df['price']
# Out:
# 23820    11886
# 23821    11886
# 23822    11888
# 23823    11888
# 23824    11888
#          ...
# 27745    18803
# 27746    18804
# 27747    18806
# 27748    18818
# 27749    18823
# Name: price, Length: 3540, dtype: int64

# %%
species=['setosa','versicolor','viriginica']
sepal_length=[5.1,6.2,6.9,5.6,6.7,6.8,5.7,6.4,6.3]
species_data=['setosa','versicolor','virginica','setosa','versicolor','virginica','setosa','versicolor','virginica']

sns.swarmplot(x=species_data,y=sepal_length)
plt.xlabel('species')
plt.ylabel('sepal_length')
plt.title('swarm plot of sepal length by species')
plt.show()

# %%
cars = pd.read_csv(r"E:\Adv Analytics\Datasets\Cars93.csv")
cars
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8        25
# 1         Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2          Audi       90  Compact       25.9   29.1       32.3        20
# 3          Audi      100  Midsize       30.8   37.7       44.6        19
# 4           BMW     535i  Midsize       23.7   30.0       36.2        22
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91        Volvo      240  Compact       21.8   22.7       23.5        21
# 92        Volvo      850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags DriveTrain  ... Fuel.tank.capacity  \
# ...

# %% [markdown]
# ##  plot a boxplot on min price and find outliers

# %%
cars['Min.Price'].plot(kind='box')
plt.show()

# %% [markdown]
# ##  plot a boxplot on max price and find outliers

# %%
cars['Max.Price'].plot(kind='box')
plt.show()

# %%
plt.boxplot(cars['Max.Price'])
plt.show()

# %%
import seaborn as sns
sns.boxplot(data=cars['Max.Price'])
# Out:
# <Axes: >

# %%
sns.boxplot(y='Max.Price', data= cars)
# Out:
# <Axes: ylabel='Max.Price'>

# %% [markdown]
# ## find the outliers in the min and max price column

# %%
def detect_outliers_iqr(data):
    data = sorted(data)
    q1=np.percentile(data,25)
    q3=np.percentile(data,75)
    #print (q1,q3)
    IQR = q3-q1
    lwr_bound = q1-(1.5*IQR)
    upr_bound = q3+(1.5*IQR)
    #print(lwr_bound,upr_bound)
    outliers = []
    for i in data:
        if(i<lwr_bound or i>upr_bound):
            outliers.append(i)
    return outliers #driver code

# %%
sample_outliers = detect_outliers_iqr(cars['Min.Price'])
print("outliers from IQR method ", sample_outliers)
# Out:
# outliers from IQR method  [34.6, 34.7, 37.5, 43.8, 45.4]

# %%
sample_outliers = detect_outliers_iqr(cars['Max.Price'])
print("outliers from IQR method ", sample_outliers)
# Out:
# outliers from IQR method  [41.5, 42.7, 44.6, 50.4, 80.0]

# %% [markdown]
# ## find small cars from cars data  set by using type attributr and detect outliers on below

# %%
small_cars = [cars["Type"] == "Small"]
small_cars
# Out:
# [0      True
#  1     False
#  2     False
#  3     False
#  4     False
#        ...
#  88    False
#  89    False
#  90    False
#  91    False
#  92    False
#  Name: Type, Length: 93, dtype: bool]

# %%
small_cars = cars[cars["Type"]=="Small"]
small_cars
# Out:
#    Manufacturer    Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra  Small       12.9   15.9       18.8        25
# 22        Dodge     Colt  Small        7.9    9.2       10.6        29
# 23        Dodge   Shadow  Small        8.4   11.3       14.2        23
# 28        Eagle   Summit  Small        7.9   12.2       16.5        29
# 30         Ford  Festiva  Small        6.9    7.4        7.9        31
# 31         Ford   Escort  Small        8.4   10.1       11.9        23
# 38          Geo    Metro  Small        6.7    8.4       10.0        46
# 41        Honda    Civic  Small        8.4   12.1       15.8        42
# 43      Hyundai    Excel  Small        6.8    8.0        9.2        29
# 44      Hyundai  Elantra  Small        9.0   10.0       11.0        22
# 52        Mazda      323  Small        7.4    8.3        9.1        29
# 53        Mazda  Protege  Small       10.9   11.6       12.3        28
# ...

# %% [markdown]
# ### on column (Min.Price,Price,Max.Price,MPG.city)

# %%
select_col = small_cars[['Min.Price','Price','Max.Price','MPG.city']]
select_col
# Out:
#     Min.Price  Price  Max.Price  MPG.city
# 0        12.9   15.9       18.8        25
# 22        7.9    9.2       10.6        29
# 23        8.4   11.3       14.2        23
# 28        7.9   12.2       16.5        29
# 30        6.9    7.4        7.9        31
# 31        8.4   10.1       11.9        23
# 38        6.7    8.4       10.0        46
# 41        8.4   12.1       15.8        42
# 43        6.8    8.0        9.2        29
# 44        9.0   10.0       11.0        22
# 52        7.4    8.3        9.1        29
# 53       10.9   11.6       12.3        28
# 61        7.7   10.3       12.9        29
# 63        8.7   11.8       14.9        29
# 72        8.2    9.0        9.9        31
# 78        9.2   11.1       12.9        28
# 79        7.3    8.4        9.5        33
# 80       10.5   10.9       11.3        25
# 82        7.3    8.6       10.0        39
# 83        7.8    9.8       11.8        32
# 87        8.7    9.1        9.5        25

# %%
select_col.boxplot()
# Out:
# <Axes: >

# %%
for i in select_col.columns:
    outliers= detect_outliers_iqr(select_col[i])
    print(i,outliers)
# Out:
# Min.Price [10.9, 12.9]
# Price [15.9]
# Max.Price [18.8]
# MPG.city [42, 46]

# %% [markdown]
# ## Load Salaries Data sets

# %%
salaries = pd.read_csv(r"E:\Adv Analytics\Datasets\Salaries.csv")
salaries
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %% [markdown]
# ## Find outliers on Salary and  yrs.services

# %%
plt.boxplot(salaries['salary'])
plt.show()

# %%
sns.boxplot(data=salaries['salary'])
plt.show()

# %%
sns.boxplot(data=salaries['yrs.service'])
plt.show()

# %%
sample_outliers = detect_outliers_iqr(salaries['salary'])
print("outliers from IQR method ", sample_outliers)
# Out:
# outliers from IQR method  [204000, 205500, 231545]

# %%
sample_outliers = detect_outliers_iqr(salaries['yrs.service'])
print("outliers from IQR method ", sample_outliers)
# Out:
# outliers from IQR method  [60]

# %%
for i in select_col.columns:
    outliers= detect_outliers_iqr(select_col[i])
    print(i,outliers)

# %% [markdown]
# ## find the outliers for male and female based on salary attribute respectively

# %%
male_salaries = salaries[salaries["sex"] == "Male"]
male_salaries
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [358 rows x 6 columns]

# %%
plt.boxplot(male_salaries['salary'])
plt.show()

# %%
sample_outliers = detect_outliers_iqr(male_salaries['salary'])
print("outliers from IQR method ", sample_outliers)
# Out:
# outliers from IQR method  [204000, 205500, 231545]

# %%
female_salaries = salaries[salaries["sex"] == "Female"]
female_salaries
# Out:
#           rank discipline  yrs.since.phd  yrs.service     sex  salary
# 9         Prof          B             18           18  Female  129000
# 19        Prof          A             39           36  Female  137000
# 24   AssocProf          A             13            8  Female   74830
# 34    AsstProf          B              4            2  Female   80225
# 35    AsstProf          B              5            0  Female   77000
# 47        Prof          B             23           19  Female  151768
# 48        Prof          B             25           25  Female  140096
# 52    AsstProf          B             11            3  Female   74692
# 63   AssocProf          B             11           11  Female  103613
# 68        Prof          B             17           17  Female  111512
# 84        Prof          B             17           18  Female  122960
# 90    AsstProf          B             10            5  Female   97032
# ...

# %%
plt.boxplot(female_salaries['salary'])
plt.show()
