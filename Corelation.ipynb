# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1) Load Iris data set

# %%
iris = pd.read_csv(r"E:\Adv Analytics\Datasets\iris.csv")
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 2) find the correlation on iris data set

# %%
iris.corr()
# Out:
# C:\Users\KARTIK\AppData\Local\Temp\ipykernel_7004\2141086772.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris.corr()
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Sepal.Length      1.000000    -0.117570      0.871754     0.817941
# Sepal.Width      -0.117570     1.000000     -0.428440    -0.366126
# Petal.Length      0.871754    -0.428440      1.000000     0.962865
# Petal.Width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# # 3) plot the Heatmap on iris data set using seaborn

# %%
sns.heatmap(iris.corr(), annot=True)
plt.show()
# Out:
# C:\Users\KARTIK\AppData\Local\Temp\ipykernel_7004\2433616931.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(iris.corr(), annot=True)

# %% [markdown]
# # 4) Plot the scatter plot on Sepal length Vs Petal width

# %%
sns.scatterplot(x='Sepal.Length', y='Petal.Width',data = iris)
plt.show()

# %% [markdown]
# # 5) Load the Car93 data set

# %%
cars = pd.read_csv(r"E:\Adv Analytics\Datasets\Cars93.csv")
cars
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8        25
# 1         Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2          Audi       90  Compact       25.9   29.1       32.3        20
# 3          Audi      100  Midsize       30.8   37.7       44.6        19
# 4           BMW     535i  Midsize       23.7   30.0       36.2        22
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91        Volvo      240  Compact       21.8   22.7       23.5        21
# 92        Volvo      850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags DriveTrain  ... Fuel.tank.capacity  \
# ...

# %% [markdown]
# # 6) Find correlection on Cars93 dat sets

# %%
cars.corr()
# Out:
# C:\Users\KARTIK\AppData\Local\Temp\ipykernel_15944\4092122903.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cars.corr()
#                     Min.Price     Price  Max.Price  MPG.city  MPG.highway  \
# Min.Price            1.000000  0.970601   0.906756 -0.622875    -0.579966
# Price                0.970601  1.000000   0.981580 -0.594562    -0.560680
# Max.Price            0.906756  0.981580   1.000000 -0.547811    -0.522561
# MPG.city            -0.622875 -0.594562  -0.547811  1.000000     0.943936
# MPG.highway         -0.579966 -0.560680  -0.522561  0.943936     1.000000
# EngineSize           0.645488  0.597425   0.535012 -0.710003    -0.626795
# Horsepower           0.802444  0.788218   0.744445 -0.672636    -0.619044
# RPM                 -0.042598 -0.004955   0.025015  0.363045     0.313469
# ...

# %%
col = cars[['Min.Price','Price','Max.Price','MPG.city']]
col.corr()
# Out:
#            Min.Price     Price  Max.Price  MPG.city
# Min.Price   1.000000  0.970601   0.906756 -0.622875
# Price       0.970601  1.000000   0.981580 -0.594562
# Max.Price   0.906756  0.981580   1.000000 -0.547811
# MPG.city   -0.622875 -0.594562  -0.547811  1.000000

# %%
cars.iloc[:,3:7].corr()
# Out:
#            Min.Price     Price  Max.Price  MPG.city
# Min.Price   1.000000  0.970601   0.906756 -0.622875
# Price       0.970601  1.000000   0.981580 -0.594562
# Max.Price   0.906756  0.981580   1.000000 -0.547811
# MPG.city   -0.622875 -0.594562  -0.547811  1.000000

# %% [markdown]
# # 7) plot the Scatter on Min Price Vs Max Price

# %%
sns.scatterplot(x='Min.Price',y='Max.Price',data=cars)
plt.show()

# %% [markdown]
# # 8) Load Salaries data set

# %%
salaries=pd.read_csv(r"E:\Adv Analytics\Datasets\Salaries.csv")
salaries
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %%
salaries.corr()
# Out:
# C:\Users\KARTIK\AppData\Local\Temp\ipykernel_15944\3094442422.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   salaries.corr()
#                yrs.since.phd  yrs.service    salary
# yrs.since.phd       1.000000     0.909649  0.419231
# yrs.service         0.909649     1.000000  0.334745
# salary              0.419231     0.334745  1.000000

# %% [markdown]
# # 9) Plot the Heat Map on Salaries Data sets

# %%
sns.heatmap(salaries.corr(), annot=True)
plt.show()
# Out:
# C:\Users\KARTIK\AppData\Local\Temp\ipykernel_15944\2891297153.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(salaries.corr(), annot=True)

# %% [markdown]
# # 10) Load the milk data set

# %%
milk = pd.read_csv(r"E:\Adv Analytics\Datasets\milk.csv")
milk
# Out:
#         Animal  water  protein   fat  lactose   ash
# 0        HORSE   90.1      2.6   1.0      6.9  0.35
# 1    ORANGUTAN   88.5      1.4   3.5      6.0  0.24
# 2       MONKEY   88.4      2.2   2.7      6.4  0.18
# 3       DONKEY   90.3      1.7   1.4      6.2  0.40
# 4        HIPPO   90.4      0.6   4.5      4.4  0.10
# 5        CAMEL   87.7      3.5   3.4      4.8  0.71
# 6        BISON   86.9      4.8   1.7      5.7  0.90
# 7      BUFFALO   82.1      5.9   7.9      4.7  0.78
# 8   GUINEA PIG   81.9      7.4   7.2      2.7  0.85
# 9          CAT   81.6     10.1   6.3      4.4  0.75
# 10         FOX   81.6      6.6   5.9      4.9  0.93
# 11       LLAMA   86.5      3.9   3.2      5.6  0.80
# 12        MULE   90.0      2.0   1.8      5.5  0.47
# 13         PIG   82.8      7.1   5.1      3.7  1.10
# 14       ZEBRA   86.2      3.0   4.8      5.3  0.70
# 15       SHEEP   82.0      5.6   6.4      4.7  0.91
# 16         DOG   76.3      9.3   9.5      3.0  1.20
# ...

# %%
milk.corr()
# Out:
# C:\Users\KARTIK\AppData\Local\Temp\ipykernel_15944\2685404228.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   milk.corr()
#             water   protein       fat   lactose       ash
# water    1.000000 -0.755759 -0.981870  0.863888 -0.429093
# protein -0.755759  1.000000  0.657521 -0.842193  0.806130
# fat     -0.981870  0.657521  1.000000 -0.841038  0.324658
# lactose  0.863888 -0.842193 -0.841038  1.000000 -0.599645
# ash     -0.429093  0.806130  0.324658 -0.599645  1.000000

# %% [markdown]
# # 11) Plot the Heat map on Milk data set

# %%
sns.heatmap(milk.corr(), annot=True)
plt.show()
# Out:
# C:\Users\KARTIK\AppData\Local\Temp\ipykernel_15944\329182232.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(milk.corr(), annot=True)

# %% [markdown]
# # 12) Find highest Postive correltion attribute by using correlation matrix

# %%
# water and lactose , ash and protien

# %% [markdown]
# # 13) Find the kurtosis on Water and  Lactose and plot the histrogram

# %%
milk['water'].kurtosis()
# Out:
# 1.4848124858107647

# %%
plt.hist(milk['water'])
plt.show()

# %%
milk['lactose'].kurtosis()
# Out:
# -0.4555522990602916

# %%
plt.hist(milk['lactose'])
plt.show()

# %% [markdown]
# # 14) Plot the Distplot on water and lactose

# %%
sns.distplot(milk['water'])
plt.show()
# Out:
# C:\Users\KARTIK\AppData\Local\Temp\ipykernel_15944\573516407.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(milk['water'])

# %%
sns.distplot(milk['lactose'])
plt.show()
# Out:
# C:\Users\KARTIK\AppData\Local\Temp\ipykernel_15944\667929012.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(milk['lactose'])
