# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"E:\csv files\Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df['SepalLengthCm'].plot(kind='box')
plt.show()

# %%
df['SepalLengthCm'].plot(kind='hist')
plt.show()

# %%
df['SepalLengthCm'].head(20).plot(kind='pie')
plt.show()

# %%
df.plot(kind='box')
plt.show()

# %%
df=df.drop(columns="Id")
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.plot(kind='box')
plt.show()

# %%
df.iloc[0:50].plot(kind='box')
plt.show()

# %%
df.iloc[:,[2,3]].plot(kind='box')
plt.show()

# %%
import seaborn as sns

# %%
sns.boxplot(y="SepalLengthCm",data=df)
plt.show()

# %%
sns.barplot(x="SepalLengthCm",y="PetalLengthCm", data=df.head())
plt.show()

# %%
sns.histplot(x="SepalLengthCm",y="PetalLengthCm", data=df.head())
plt.show()

# %%
df['SepalLengthCm'].plot(kind='hist',color="red")
plt.show()

# %%
df['SepalLengthCm'].plot(kind='hist',color="red",alpha=0.4,bins=20)
plt.show()

# %%
df['SepalLengthCm'].plot(kind='hist',color="red",alpha=0.4,bins=20)
plt.show()

# %%
df['SepalLengthCm'].plot(kind='hist',color="red",alpha=0.4,bins=20)
plt.title('Sepal graph')
plt.xlabel('sepal length')
plt.show()

# %%
plt.stem(df['Species'],df['SepalLengthCm'])
plt.title('Sepal graph')
plt.xlabel('sepal length')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
name=['kartik','cr7','messi','virat','rohit','surya']
age=[50,40,60,31,60,40]
zipped=list(zip(name,age))

team = pd.DataFrame(zipped,columns=['Names','Age'])
team
# Out:
#     Names  Age
# 0  kartik   50
# 1     cr7   40
# 2   messi   60
# 3   virat   31
# 4   rohit   60
# 5   surya   40

# %%
team.plot(kind='hist',color="red",alpha=0.4)
plt.title('Histogram')
plt.xlabel("Age")
plt.ylabel("no of person")
plt.show()

# %%
cntname=team['Age'].value_counts()
cntname
cntname.plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.scatter(df['SepalLengthCm'],df['PetalLengthCm'])
plt.show()

# %%
count=df['Species'].value_counts()
count
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
count.plot(kind='bar')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
count.plot(kind='bar',color=['red','green','blue'])
plt.show()

# %%
import pandas as pd
order=pd.read_csv(r"E:\csv files\Orders.csv")
order
# Out:
#      Order ID Order Date Place of Shipment Payment Terms
# 0   32 90 001  31-Dec-10              Pune        Cheque
# 1   32 90 002   6-Jan-11             Nasik        Online
# 2   32 90 003  14-Jan-11        Ahmednagar          Cash
# 3   32 90 004  18-Feb-11            Nanded        Cheque
# 4   32 90 005  19-Feb-11          Kolhapur          Cash
# ..        ...        ...               ...           ...
# 65  32 90 066  13-Jul-13          Nadurbar        Cheque
# 66  32 90 067  23-Jul-13             Dhule        Cheque
# 67  32 90 068   2-Aug-13         Ratnagiri        Online
# 68  32 90 069   4-Sep-13             Dhule        Cheque
# 69  32 90 070   7-Sep-13         Ratnagiri        Cheque
#
# [70 rows x 4 columns]

# %%
cntarea=order['Place of Shipment'].value_counts()
cntarea
# Out:
# Ratnagiri      8
# Raigad         5
# Sindhudurga    5
# Dhule          5
# Thane          4
# Nasik          4
# Aurangabad     4
# Pune           4
# Mumbai         3
# Nanded         3
# Ahmednagar     3
# Goa            3
# Solapur        3
# Sangli         3
# Satara         3
# Nagpur         3
# Nadurbar       3
# Kolhapur       2
# Buldhana       2
# Name: Place of Shipment, dtype: int64

# %%
cntarea.plot(kind='bar')
plt.show()

# %%
cntarea.plot(kind='barh')
plt.show()

# %%
cnt=order['Payment Terms'].value_counts()
cnt.plot(kind='bar')
plt.xlabel('Payment term')
plt.xticks(rotation=30)
plt.ylabel('count')
plt.show()

# %%
val=order['Payment Terms'].value_counts()
val
# Out:
# Online    29
# Cheque    23
# Cash      18
# Name: Payment Terms, dtype: int64

# %%
val.plot(kind='pie')
plt.show()

# %%
val.plot(kind='pie',autopct="%.f%%")
plt.show()

# %%
val.plot(kind='pie',autopct="%.2f%%")
plt.show()

# %%
df['SepalLengthCm'].plot(kind='kde')
plt.show()

# %%
import seaborn as sns
sns.countplot(x='Payment Terms',data=order)
plt.show()

# %%
sns.boxplot(x='Species',y='SepalLengthCm', data=df)
plt.show()

# %%
sns.boxplot(x='SepalLengthCm',y='Species', data=df)
plt.show()

# %%
sns.scatterplot(x='SepalLengthCm',y='SepalWidthCm',hue='Species',data=df)
plt.show()

# %%
order
# Out:
#      Order ID Order Date Place of Shipment Payment Terms
# 0   32 90 001  31-Dec-10              Pune        Cheque
# 1   32 90 002   6-Jan-11             Nasik        Online
# 2   32 90 003  14-Jan-11        Ahmednagar          Cash
# 3   32 90 004  18-Feb-11            Nanded        Cheque
# 4   32 90 005  19-Feb-11          Kolhapur          Cash
# ..        ...        ...               ...           ...
# 65  32 90 066  13-Jul-13          Nadurbar        Cheque
# 66  32 90 067  23-Jul-13             Dhule        Cheque
# 67  32 90 068   2-Aug-13         Ratnagiri        Online
# 68  32 90 069   4-Sep-13             Dhule        Cheque
# 69  32 90 070   7-Sep-13         Ratnagiri        Cheque
#
# [70 rows x 4 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(df['SepalLengthCm'])
plt.show()
# Out:
# C:\Users\KARTIK\AppData\Local\Temp\ipykernel_3600\2320928467.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SepalLengthCm'])

# %%
sepal=df['SepalLengthCm'].mean()
sepal
# Out:
# 5.843333333333334

# %%
g = sns.FacetGrid(df,col="Species")
g.map(plt.hist,"SepalLengthCm")
plt.show()

# %%
g = sns.FacetGrid(df,row="Species")
g.map(plt.hist,"SepalLengthCm")
plt.show()

# %%
g=sns.FacetGrid(df,col='Species')
g.map(plt.scatter,"SepalLengthCm","SepalWidthCm")
plt.show()

# %%
#jointplot

sns.jointplot(x='SepalLengthCm', y= 'SepalWidthCm',data=df)
plt.show()

sns.jointplot(x="SepalLengthCm",y='SepalWidthCm',data=df,kind='reg')
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(df,hue="Species")
plt.show()

# %%
plt.hist(df["SepalLengthCm"])
plt.show()

# %%
plt.hist(df["SepalLengthCm"],bins=7)
plt.show()
print(df['SepalLengthCm'].skew())
# Out:
# 0.3149109566369728

# %%
plt.hist(df["SepalWidthCm"],bins=7)
plt.show()
print(df['SepalWidthCm'].skew())
# Out:
# 0.3340526621720866

# %%
plt.hist(df["PetalLengthCm"],bins=10)
plt.show()
print(df['PetalLengthCm'].skew())
# Out:
# -0.27446425247378287

# %%
plt.hist(df["PetalLengthCm"],bins=7)
plt.show()
print(df['PetalLengthCm'].skew())
# Out:
# -0.27446425247378287

# %%
plt.hist(df["PetalWidthCm"],bins=10)
plt.show()
print(df['PetalWidthCm'].skew())
# Out:
# -0.10499656214412734

# %%
plt.hist(df["PetalWidthCm"],bins=7)
plt.show()
print(df['PetalWidthCm'].skew())
# Out:
# -0.10499656214412734

# %%
diamond = pd.read_csv(r"E:\Adv Analytics\Datasets\diamonds.csv")
diamond
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamond.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
plt.hist(diamond["price"],bins=7)
plt.show()
print(diamond['price'].skew())
# Out:
# 1.618395283383529

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(diamond['price'])
plt.show()
# Out:
# C:\Users\KARTIK\AppData\Local\Temp\ipykernel_11172\3437967273.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(diamond['price'])
